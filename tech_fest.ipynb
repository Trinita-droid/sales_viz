# %%
# load datset
import pandas as pd
d_set = pd.read_csv('Data_is_Fun_Final_Dataset.csv')
df = d_set.copy()
df.tail()
df.head()
df.describe()
# df
# Out:
#               Year        Month   Product_ID  Sales_Quantity   Sales_Value  \
# count  2835.000000  2838.000000  2839.000000     2864.000000  2.846000e+03
# mean   2019.005291     6.523961    50.135963       53.400353  3.291789e+04
# std       2.583054     3.483375    29.090122       44.063002  1.294566e+05
# min    2015.000000     1.000000     1.000000        0.807550  3.726764e+01
# 25%    2017.000000     3.000000    25.000000       27.458878  7.763916e+03
# 50%    2019.000000     7.000000    50.000000       52.165587  1.932882e+04
# 75%    2021.000000    10.000000    75.000000       74.947766  3.810858e+04
# max    2023.000000    12.000000   100.000000      956.877565  3.705619e+06
#
#           Discount  Marketing_Spend  Customer_Feedback
# count  2847.000000      2826.000000        2851.000000
# mean     25.471563      1428.009816           3.032971
# std      15.998147      1542.535752           1.432076
# min       0.019304         3.597657           1.000000
# ...

# %%
df
# Out:
#         Year  Month  Product_ID Product_Category Product_Subcategory  \
# 0     2020.0    2.0         NaN       Home Goods              Comics
# 1     2018.0   10.0        76.0         Clothing       Mixer Grinder
# 2     2022.0    3.0        89.0       Home Goods         Educational
# 3     2018.0    7.0        66.0      Accessories             Fiction
# 4     2021.0    3.0        92.0         Clothing               Saree
# ...      ...    ...         ...              ...                 ...
# 3145  2022.0    4.0        37.0      Accessories             T-shirt
# 3146  2015.0    NaN        19.0      Electronics                 NaN
# 3147  2022.0   12.0        89.0         Clothing        Refrigerator
# 3148  2016.0   11.0        53.0         Clothing               Boots
# 3149  2023.0    NaN        73.0      Electronics                 NaN
#
#              Product_Name    Brand  Sales_Quantity   Sales_Value   Discount  \
# ...

# %%
# pre-cleaning - dropping duplicates
df = df.drop_duplicates()
df
# Out:
#         Year  Month  Product_ID Product_Category Product_Subcategory  \
# 0     2020.0    2.0         NaN       Home Goods              Comics
# 1     2018.0   10.0        76.0         Clothing       Mixer Grinder
# 2     2022.0    3.0        89.0       Home Goods         Educational
# 3     2018.0    7.0        66.0      Accessories             Fiction
# 4     2021.0    3.0        92.0         Clothing               Saree
# ...      ...    ...         ...              ...                 ...
# 2995  2018.0    4.0        27.0         Clothing                 NaN
# 2996     NaN    1.0         NaN            Books          Headphones
# 2997  2018.0    7.0        28.0      Accessories                 NaN
# 2998  2021.0    5.0        47.0         Footwear         Educational
# 2999  2020.0   11.0        30.0      Electronics                Sofa
#
#              Product_Name    Brand  Sales_Quantity   Sales_Value   Discount  \
# ...

# %%
# drops the row if any vaue is null
df = df.dropna()
df
# Out:
#         Year  Month  Product_ID Product_Category Product_Subcategory  \
# 50    2018.0   12.0        19.0      Electronics               Boots
# 66    2020.0   12.0        93.0         Footwear              Jacket
# 74    2023.0    7.0        45.0       Home Goods        Mobile Phone
# 106   2022.0   12.0        17.0             Toys               Saree
# 164   2021.0    1.0        42.0      Accessories              LED TV
# ...      ...    ...         ...              ...                 ...
# 2905  2022.0    1.0         8.0       Home Goods              Tablet
# 2933  2023.0    2.0        42.0         Footwear             Sandals
# 2950  2023.0    8.0        68.0         Footwear               Chair
# 2961  2021.0   12.0         4.0      Electronics      Action Figures
# 2990  2016.0    6.0         8.0         Clothing               Chair
#
#        Product_Name    Brand  Sales_Quantity   Sales_Value   Discount  \
# ...

# %%
#sample viz
plt.figure(figsize=(10, 5))
plt.plot(df['Order_Status'], df['Customer_Age_Group'], marker='o', label='Customer_Age_Group')
plt.plot(df['Order_Status'], df['Sales_Channel'], marker='o', label='Sales_Channel')
plt.xlabel('status')
plt.ylabel('age')
plt.title('Sales and Profit Over Time')
plt.legend()
plt.grid(True)
plt.show()

# %%
# separate viz
import matplotlib.pyplot as plt
import seaborn as sns

# Setting the style for the plot
sns.set(style="whitegrid")

# Creating the plot
plt.figure(figsize=(6, 6))
can_df = df[df['Order_Status'] == 'Cancelled']
sns.barplot(x=df['Customer_Age_Group'], y=df['Marketing_Spend'], data=can_df)

# Adding labels and title
plt.xlabel('Customer_Age_Group')
plt.ylabel('Marketing_Spend')
plt.title('Delivery Status by Marketing_Spend')
plt.legend(title='Status')

# Displaying the plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt

# Create the plot
plt.figure(figsize=(10, 5))
watches_values = df[df['Product_Subcategory'] == 'Watches']
plt.bar('Product_Category','watches_values', color='skyblue')

# Add labels and title
plt.xlabel('Product_Subcategory')
plt.ylabel('Customer Review (out of 5)')
plt.title('Customer Review by Product_Subcategory')

# Show plot
plt.show()

# %%
df
# Out:
#         Year  Month  Product_ID Product_Category Product_Subcategory  \
# 0     2020.0    2.0         NaN       Home Goods              Comics
# 1     2018.0   10.0        76.0         Clothing       Mixer Grinder
# 2     2022.0    3.0        89.0       Home Goods         Educational
# 3     2018.0    7.0        66.0      Accessories             Fiction
# 4     2021.0    3.0        92.0         Clothing               Saree
# ...      ...    ...         ...              ...                 ...
# 3145  2022.0    4.0        37.0      Accessories             T-shirt
# 3146  2015.0    NaN        19.0      Electronics                 NaN
# 3147  2022.0   12.0        89.0         Clothing        Refrigerator
# 3148  2016.0   11.0        53.0         Clothing               Boots
# 3149  2023.0    NaN        73.0      Electronics                 NaN
#
#              Product_Name    Brand  Sales_Quantity   Sales_Value   Discount  \
# ...

# %%
# df["Region"] = df["Region"].str.replace('[^a-zA-Z0-9]','')
# df["Phone_Number"]
df['Region'] = df['Region'].replace({'North India': 'India', 'South India': 'India'})
df["Region"]
import matplotlib.pyplot as plt

# Create the plot
plt.figure(figsize=(10, 6))
plt.bar(df['Region'], df['Customer_Feedback'], color='lightgreen')

# Add labels and title
plt.xlabel('Region')
plt.ylabel('Feedback Score (out of 5)')
plt.title('Feedback Score by Region')

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Setting the style for the plot
sns.set(style="whitegrid")

# Creating the plot
plt.figure(figsize=(10, 5))
sns.barplot(x='Order_Status', y='Region', data=df)

# Adding labels and title
plt.xlabel('Order_Status')
plt.ylabel('Region')
plt.title('Order Status vs. Region')

# Show plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Setting the style and color palette for the plot
sns.set(style="whitegrid")
colors = sns.color_palette("pastel")

# Creating the plot with error bars and annotations
plt.figure(figsize=(10, 6))
ax = sns.barplot(x='Order_Status', y='Discount', data=df, ci="sd", capsize=0.1, palette=colors)

# Adding error bars to the plot
for i, bar in enumerate(ax.patches):
    y_val = bar.get_height()
    ax.text(bar.get_x() + bar.get_width() / 2, y_val + 0.5, f'{y_val:.1f}', ha='center', va='bottom', fontsize=10)

# Adding labels and title
plt.xlabel('Order_Status', fontsize=12)
plt.ylabel('Discount', fontsize=12)
plt.title('Order Status vs. Discount', fontsize=14)

# Show plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\TJO1COB\AppData\Local\Temp\ipykernel_12284\3211539798.py:10: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   ax = sns.barplot(x='Order_Status', y='Discount', data=df, ci="sd", capsize=0.1, palette=colors)
# C:\Users\TJO1COB\AppData\Local\Temp\ipykernel_12284\3211539798.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x='Order_Status', y='Discount', data=df, ci="sd", capsize=0.1, palette=colors)
# C:\Users\TJO1COB\AppData\Local\Temp\ipykernel_12284\3211539798.py:10: UserWarning: The palette list has more values (10) than needed (3), which may not be intended.
#   ax = sns.barplot(x='Order_Status', y='Discount', data=df, ci="sd", capsize=0.1, palette=colors)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Setting the style for the plot
sns.set(style="whitegrid")

# Creating the plot
plt.figure(figsize=(10, 6))
sns.swarmplot(x='Order_Status', y='Discount', data=df, palette='pastel')

# Adding labels and title
plt.xlabel('Order_Status', fontsize=12)
plt.ylabel('Discount', fontsize=12)
plt.title('Order Status vs. Discount', fontsize=14)

# Show plot
plt.tight_layout()
plt.show()
# Out:
# C:\Users\TJO1COB\AppData\Local\Temp\ipykernel_12284\2260518029.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.swarmplot(x='Order_Status', y='Discount', data=df, palette='pastel')

# %%
# Group the data by Year and Brand and calculate the sum of Sales_Value
sales_by_year_brand = filled_df.groupBy("Year", "Brand").sum("Sales_Value")
 
# Convert the grouped DataFrame to Pandas DataFrame for visualization
pandas_df = sales_by_year_brand.toPandas()
 
# Create a scatter plot
plt.scatter(pandas_df["Year"], pandas_df["sum(Sales_Value)"])
 
# Adding labels and title
plt.xlabel('Year')
plt.ylabel('Sales Value')
plt.title('Total Sales Value by Year and Brand')
 
# Display the plot
plt.show()
 
# Display the DataFrame
display(sales_by_year_brand)

# %%
import matplotlib.pyplot as plt
 
# Convert the sales_by_year_brand DataFrame to Pandas DataFrame
sales_by_year_brand_pd = sales_by_year_brand.toPandas()
 
# Plot the sales quantity by product
plt.figure(figsize=(12, 6))
sales_by_year_brand_pd.groupby('Brand')['sum(Sales_Value)'].sum().plot(kind='bar')
plt.xlabel('Brand')
plt.ylabel('Sales Quantity')
plt.title('Sales Quantity by Brand')
plt.show()

# %%
df
# Out:
#         Year  Month  Product_ID Product_Category Product_Subcategory  \
# 0     2020.0    2.0         NaN       Home Goods              Comics
# 1     2018.0   10.0        76.0         Clothing       Mixer Grinder
# 2     2022.0    3.0        89.0       Home Goods         Educational
# 3     2018.0    7.0        66.0      Accessories             Fiction
# 4     2021.0    3.0        92.0         Clothing               Saree
# ...      ...    ...         ...              ...                 ...
# 2995  2018.0    4.0        27.0         Clothing                 NaN
# 2996     NaN    1.0         NaN            Books          Headphones
# 2997  2018.0    7.0        28.0      Accessories                 NaN
# 2998  2021.0    5.0        47.0         Footwear         Educational
# 2999  2020.0   11.0        30.0      Electronics                Sofa
#
#              Product_Name    Brand  Sales_Quantity   Sales_Value   Discount  \
# ...

# %%
df.isna
# Out:
# <bound method DataFrame.isna of         Year  Month  Product_ID Product_Category Product_Subcategory  \
# 0     2020.0    2.0         NaN       Home Goods              Comics
# 1     2018.0   10.0        76.0         Clothing       Mixer Grinder
# 2     2022.0    3.0        89.0       Home Goods         Educational
# 3     2018.0    7.0        66.0      Accessories             Fiction
# 4     2021.0    3.0        92.0         Clothing               Saree
# ...      ...    ...         ...              ...                 ...
# 2995  2018.0    4.0        27.0         Clothing                 NaN
# 2996     NaN    1.0         NaN            Books          Headphones
# 2997  2018.0    7.0        28.0      Accessories                 NaN
# 2998  2021.0    5.0        47.0         Footwear         Educational
# 2999  2020.0   11.0        30.0      Electronics                Sofa
#
#              Product_Name    Brand  Sales_Quantity   Sales_Value   Discount  \
# ...
